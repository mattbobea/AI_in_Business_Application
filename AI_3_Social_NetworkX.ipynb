# %% [markdown]
# <a href="https://colab.research.google.com/github/mattbobea/AI_in_Business_Application-/blob/main/AI_3_Social_NetworkX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_edge(1, 2)
G.add_edge(1, 3)
G.add_edge(1, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)

# explicitly set positions (x,y)
pos = {1: (0, 0), 2: (-1, 0.3), 3: (2, 0.17), 4: (4, 0.255), 5: (5, 0.03)}

options = {
    "font_size": 36,
    "node_size": 3000,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 5,
    "width": 5,
}
nx.draw_networkx(G, pos, **options)

# Set margins for the axes so that nodes aren't clipped
ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# %%
import pandas as pd



# Edges
df_edges = pd.DataFrame({
    'source': ['John', 'John', 'Jane', 'Alice', 'Tom', 'Helen', 'William'],
    'target': ['Jane', 'Helen', 'Tom', 'Tom', 'Helen', 'William', 'Alice'],
    'years': [2, 3, 5, 1, 2, 8, 3]
})
# Nodes
df_nodes = pd.DataFrame({
    'Name': ['John', 'Jane', 'Alice', 'Tom', 'Helen', 'William'],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male']
})
node_colors = {'Male': 'blue', 'Female': 'red'}
df_nodes['node_color'] = df_nodes['Gender'].map(node_colors)
G = nx.from_pandas_edgelist(df_edges, source = 'source', target = 'target', edge_attr = 'years')

nodes_attr = df_nodes.set_index('Name').to_dict(orient = 'index')
nx.set_node_attributes(G, nodes_attr)



plt.figure(figsize=(6,6)) 
nx.draw_networkx(G, 
    pos = nx.kamada_kawai_layout(G, weight = 'years'), 
    node_size = 200, 
    node_color = [G.nodes[n]['node_color'] for n in G.nodes],
    width = [G.edges[e]['years'] for e in G.edges],
    with_labels = True)
plt.plot()
# Out:
# []

# %%
df_nodes
# Out:
#       Name  Gender node_color
# 0     John    Male       blue
# 1     Jane  Female        red
# 2    Alice  Female        red
# 3      Tom    Male       blue
# 4    Helen  Female        red
# 5  William    Male       blue

# %%
df_edges
# Out:
#     source   target  years
# 0     John     Jane      2
# 1     John    Helen      3
# 2     Jane      Tom      5
# 3    Alice      Tom      1
# 4      Tom    Helen      2
# 5    Helen  William      8
# 6  William    Alice      3

# %%
# !rm demo*.xlsx
# Out:
# rm: cannot remove 'demo*.xlsx': No such file or directory

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-286924d1-0fe0-470d-98f2-25a2e9a7bd33" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-286924d1-0fe0-470d-98f2-25a2e9a7bd33">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df_nodes1 = pd.read_excel('demo.xlsx', sheet_name="node")
df_nodes1
# Out:
#       Name  Gender node_color
# 0     John    Male       blue
# 1     Jane  Female        red
# 2    Alice  Female        red
# 3      Tom    Male       blue
# 4    Helen  Female        red
# 5  William    Male       blue
# 6     Mary  Female        red

# %%
df_edges1 = pd.read_excel('demo.xlsx', sheet_name="edge")
df_edges1
# Out:
#     source   target  years
# 0     John     Jane      2
# 1     John    Helen      3
# 2     Jane      Tom      5
# 3    Alice      Tom      1
# 4      Tom    Helen      2
# 5    Helen  William      8
# 6  William    Alice      3
# 7     Mary    Alice     20

# %%
G1 = nx.from_pandas_edgelist(df_edges1, source = 'source', target = 'target', edge_attr = 'years')

nodes_attr = df_nodes1.set_index('Name').to_dict(orient = 'index')
nx.set_node_attributes(G1, nodes_attr)



plt.figure(figsize=(6,6)) 
nx.draw_networkx(G1, 
    pos = nx.kamada_kawai_layout(G1, weight = 'years'), 
    node_size = 200, 
    node_color = [G1.nodes[n]['node_color'] for n in G1.nodes],
    width = [G1.edges[e]['years'] for e in G1.edges],
    with_labels = True)
plt.plot()
# Out:
# []
